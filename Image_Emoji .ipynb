# %%
train_folder = "C:\\Users\\susmitha kolli\\Desktop\\final_train\\"

# %%
import os 
import os
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import keras
from PIL import Image
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import BatchNormalization
from keras.models import load_model

# %%
image_list =[]
for f in os.listdir(train_folder):
    if ".jpg" in f:
        target = f.split('.')[0]
        if "happy1" in target:
            label = np.array([[1, 0, 0, 0, 0, 0]])
        elif "happy2" in target:
            label = np.array([[0, 1, 0, 0, 0, 0]])
        elif "happy3" in target:
            label = np.array([[0, 0, 1, 0, 0, 0]])
        elif "sad1" in target:
            label = np.array([[0, 0, 0, 1, 0, 0]])
        elif "sad2" in target:
            label = np.array([[0, 0, 0, 0, 1, 0]])
        elif "sad3" in target:
            label = np.array([[0, 0, 0, 0, 0, 1]])
        file_full=train_folder+"\\"+f
        image_list.append({'file':f,'file_full':file_full,'target':label})
        print(image_list)
# Out:
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.25.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.25.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.25.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.25.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.26.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.26.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.25.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.25.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.26.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.26.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.27.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.27.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}]
# ...
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.25.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.25.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.26.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.26.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.27.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.27.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.3.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.3.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.4.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.4.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.5.jpg', ' ...
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.25.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.25.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.26.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.26.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.27.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.27.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.3.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.3.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.4.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.4.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.5.jpg', ' ...
# [{'file': 'happy1.1.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.1.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.10.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.10.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.101.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.101.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.102.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.102.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.103.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.103.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.104.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.104.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.105.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.105.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.106.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.106.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.11.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.11.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.12.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.12.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.13.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.13.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.14.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.14.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.15.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.15.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.16.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.16.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.17.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.17.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.18.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.18.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.2.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.2.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.20.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.20.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.21.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.21.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.22.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.22.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.23.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.23.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.24.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.24.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.25.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.25.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.26.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.26.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.27.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.27.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.3.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.3.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.4.jpg', 'file_full': 'C:\\Users\\susmitha kolli\\Desktop\\final_train\\\\happy1.4.jpg', 'target': array([[1, 0, 0, 0, 0, 0]])}, {'file': 'happy1.5.jpg', ' ...
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
image_df = pd.DataFrame(image_list)
from sklearn.utils import shuffle
image_df = shuffle(image_df)
print(image_df.head(10))
print(image_df.shape)
# Out:
#                file                                          file_full  \
# 36   happy2.111.jpg  C:\Users\susmitha kolli\Desktop\final_train\\h...
# 89    happy3.71.jpg  C:\Users\susmitha kolli\Desktop\final_train\\h...
# 154     sad2.52.jpg  C:\Users\susmitha kolli\Desktop\final_train\\s...
# 42    happy2.30.jpg  C:\Users\susmitha kolli\Desktop\final_train\\h...
# 95    happy3.77.jpg  C:\Users\susmitha kolli\Desktop\final_train\\h...
# 33   happy2.108.jpg  C:\Users\susmitha kolli\Desktop\final_train\\h...
# 146     sad2.44.jpg  C:\Users\susmitha kolli\Desktop\final_train\\s...
# 138     sad2.36.jpg  C:\Users\susmitha kolli\Desktop\final_train\\s...
# 166     sad2.84.jpg  C:\Users\susmitha kolli\Desktop\final_train\\s...
# 75    happy3.57.jpg  C:\Users\susmitha kolli\Desktop\final_train\\h...
#
#                    target
# 36   [[0, 1, 0, 0, 0, 0]]
# 89   [[0, 0, 1, 0, 0, 0]]
# 154  [[0, 0, 0, 0, 1, 0]]
# 42   [[0, 1, 0, 0, 0, 0]]
# 95   [[0, 0, 1, 0, 0, 0]]
# 33   [[0, 1, 0, 0, 0, 0]]
# 146  [[0, 0, 0, 0, 1, 0]]
# 138  [[0, 0, 0, 0, 1, 0]]
# 166  [[0, 0, 0, 0, 1, 0]]
# 75   [[0, 0, 1, 0, 0, 0]]
# (199, 3)

# %%
rows = image_df.shape[0]

n_fold = 5
rows_by_fold = rows//n_fold 
image_df.iloc[0:rows_by_fold].shape

train1 = image_df.iloc[0:rows-rows_by_fold]
test1 = image_df.iloc[rows-rows_by_fold:rows]

train2 = pd.concat([image_df.iloc[0:rows-rows_by_fold*2],image_df.iloc[rows-rows_by_fold:rows]],0)
test2 = image_df.iloc[rows-rows_by_fold*2:rows-rows_by_fold]

train3 = pd.concat([image_df.iloc[0:rows-rows_by_fold*3],image_df.iloc[rows-rows_by_fold*2:rows]],0)
test3 = image_df.iloc[rows-rows_by_fold*3:rows-rows_by_fold*2]

train4 = pd.concat([image_df.iloc[0:rows-rows_by_fold*4],image_df.iloc[rows-rows_by_fold*3:rows]],0) 
test4 = image_df.iloc[rows-rows_by_fold*4:rows-rows_by_fold*3]

train5 = image_df.iloc[rows_by_fold:rows]
test5 = image_df.iloc[0:rows_by_fold]

# %%
def image_file_to_np(ifile,resize=(64,64)):
    pil_img = Image.open(ifile)
    pil_img = pil_img.resize(resize,Image.ANTIALIAS)
    np_img = np.asarray(pil_img)
    pil_img.close()
    return np_img.copy()


def get_brightness(inp):
    w0 = 0.21
    w1 = 0.72
    w2 = 0.07
    r = inp[:,:,0]
    g = inp[:,:,1]
    b = inp[:,:,2]
    brightness = w0*r+w1*g+w2*b
    return brightness.copy()


def inp_to_hist_brightness(inp, bins = 10):
    z = get_brightness(inp)
    y = np.histogram(z, bins = bins, range = (0,255))[0]
    x = y.reshape(1,bins)
    return x.copy()

def inp_to_hist_bycolor(inp, bins = 10, channel=0):
    z = inp[:,:,channel]
    y = np.histogram(z, bins = bins, range = (0,255))[0]
    x = y.reshape(1,bins)
    return x.copy()

def np_img_and_bright_hist(inp,bins=10):
    a = np_img_to_hist(inp,bins=bins)
    b = inp_to_hist_brightness(inp,bins=bins)
        
    return np.hstack([a,b])

def np_img_to_hist(inp,bins=10):
    return np.hstack([ np.histogram(inp[:,:,x],bins=bins, range = (0,255))[0] for x in range(3)]).reshape(1,bins*3)


def plot_hist_all(i_np_hist):
    x_bins = np.arange(0,i_np_hist.shape[1])
    for x,h in zip(x_bins,i_np_hist.flatten()):
        
        if x<10:
            c='red'
        elif x<20:
            c='green'
        elif x<30:
            c='blue'
        else:
            c ="yellow"
        plt.bar(x,h,color=c)
    plt.show()
    
    
def plot_hist(i_np_hist):
    x_bins = np.arange(0,i_np_hist.shape[1])
    for x,h in zip(x_bins,i_np_hist.flatten()):
        
        if x<10:
            c='red'
        elif x<20:
            c='green'
        else:
            c='blue'
        plt.bar(x,h,color=c)
    plt.show()
    
    
def plot_single_hist(i_np_hist, color= "red"):
    x_bins = np.arange(0,i_np_hist.shape[1])
    for x,h in zip(x_bins,i_np_hist.flatten()):
        plt.bar(x,h,color=color)
    plt.show()
    
    
def batch_hist_from_df(idf,x_col='filename',y_col='target',batch_size=4,offset=4,resize=(64,64),bins=10, mode= "rgbh"):
    start_index = offset
    rows = idf.shape[0]
    if start_index >= rows:
        start_index = start_index%rows
    end_index = start_index + batch_size
    
    if end_index>rows:
        end_index = rows
    
    tdf = idf.iloc[start_index:end_index]
    _y = np.vstack(tdf[y_col])
    
    arrays = list(map(lambda x: image_file_to_np(x,resize=resize),tdf[x_col]))
    if mode == "red":
        _x = np.vstack(list(map(lambda x: inp_to_hist_bycolor(x,bins=bins, channel =0),arrays)))
    elif mode == "green":
        _x = np.vstack(list(map(lambda x: inp_to_hist_bycolor(x,bins=bins, channel =1),arrays)))
    elif mode == "blue":
        _x = np.vstack(list(map(lambda x: inp_to_hist_bycolor(x,bins=bins, channel =2),arrays)))
    elif mode == "brightness":
        _x = np.vstack(list(map(lambda x: inp_to_hist_brightness(x,bins=bins),arrays)))
    elif mode == "rgb":
        _x = np.vstack(list(map(lambda x: np_img_to_hist(x,bins=bins),arrays)))
    elif mode =="rgbh":
        _x = np.vstack(list(map(lambda x: np_img_and_bright_hist(x,bins=bins),arrays)))
   

    return _x.copy(),_y.copy()

# %%
idf = train4

bins_per_channel = 128
# modes available are: red, blue , green, rgb, brightness
mode = "rgbh" 
mode_factor = {'red':1,'green':1,'blue':1,'rgb':3,'brightness':1, 'rgbh':4}

input_dims = bins_per_channel* mode_factor[mode]
output_classes = 6
iterations = 70
learning_rate=0.001
batch_size=10
resize_shape = (128,128)
x_col='file_full'
y_col='target'

#Model

model = Sequential()

model.add(Dense(units=16, activation='relu', input_dim=input_dims))
model.add(BatchNormalization())
model.add(Dense(units=16, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(units=16, activation='relu'))
model.add(BatchNormalization())
model.add(Dense(units=output_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.SGD(lr=learning_rate, momentum=0.9, nesterov=True))

# Iterations

rows = image_df.shape[0]
batches = int(np.ceil(rows/batch_size))

for iterx in range(iterations):
    for batch in range(batches):
        offset = batch*batch_size
        xb,yb = batch_hist_from_df(idf=idf,x_col=x_col,y_col=y_col,
                           batch_size=batch_size,offset=offset,
                            resize=resize_shape,bins=bins_per_channel,mode ="rgbh")
        
        loss = model.train_on_batch(xb, yb)
        print("Iter",iterx,"/",iterations,"Batch",batch,"/",batches,"Loss:",loss)
# Out:
# Iter 0 / 700 Batch 0 / 20 Loss: 2.6908443
# Iter 0 / 700 Batch 1 / 20 Loss: 2.3697124
# Iter 0 / 700 Batch 2 / 20 Loss: 2.2322793
# Iter 0 / 700 Batch 3 / 20 Loss: 2.802593
# Iter 0 / 700 Batch 4 / 20 Loss: 2.1362433
# Iter 0 / 700 Batch 5 / 20 Loss: 2.660811
# Iter 0 / 700 Batch 6 / 20 Loss: 2.1155016
# Iter 0 / 700 Batch 7 / 20 Loss: 2.616338
# Iter 0 / 700 Batch 8 / 20 Loss: 2.0793507
# Iter 0 / 700 Batch 9 / 20 Loss: 2.6522777
# Iter 0 / 700 Batch 10 / 20 Loss: 2.5166788
# Iter 0 / 700 Batch 11 / 20 Loss: 2.0644383
# Iter 0 / 700 Batch 12 / 20 Loss: 1.6734883
# Iter 0 / 700 Batch 13 / 20 Loss: 2.1235669
# Iter 0 / 700 Batch 14 / 20 Loss: 2.7441895
# Iter 0 / 700 Batch 15 / 20 Loss: 1.5432451
# Iter 0 / 700 Batch 16 / 20 Loss: 1.792223
# Iter 0 / 700 Batch 17 / 20 Loss: 1.8237543
# Iter 0 / 700 Batch 18 / 20 Loss: 1.8742268
# Iter 0 / 700 Batch 19 / 20 Loss: 1.9468086
# Iter 1 / 700 Batch 0 / 20 Loss: 1.4636235
# Iter 1 / 700 Batch 1 / 20 Loss: 1.5823063
# Iter 1 / 700 Batch 2 / 20 Loss: 1.669144
# Iter 1 / 700 Batch 3 / 20 Loss: 1.6347023
# Iter 1 / 700 Batch 4 / 20 Loss: 1.5150976
# Iter 1 / 700 Batch 5 / 20 Loss: 1.7258555
# Iter 1 / 700 Batch 6 / 20 Loss: 1.72526
# Iter 1 / 700 Batch 7 / 20 Loss: 2.241469
# Iter 1 / 700 Batch 8 / 20 Loss: 2.01745
# Iter 1 / 700 Batch 9 / 20 Loss: 1.8881601
# Iter 1 / 700 Batch 10 / 20 Loss: 1.9644759
# Iter 1 / 700 Batch 11 / 20 Loss: 1.4648165
# Iter 1 / 700 Batch 12 / 20 Loss: 1.6475563
# Iter 1 / 700 Batch 13 / 20 Loss: 1.8652275
# Iter 1 / 700 Batch 14 / 20 Loss: 1.9592133
# Iter 1 / 700 Batch 15 / 20 Loss: 1.2836605
# Iter 1 / 700 Batch 16 / 20 Loss: 1.3032126
# Iter 1 / 700 Batch 17 / 20 Loss: 1.3412968
# Iter 1 / 700 Batch 18 / 20 Loss: 1.5285975
# Iter 1 / 700 Batch 19 / 20 Loss: 1.6527097
# Iter 2 / 700 Batch 0 / 20 Loss: 1.4538728
# Iter 2 / 700 Batch 1 / 20 Loss: 1.3055751
# Iter 2 / 700 Batch 2 / 20 Loss: 1.4090397
# Iter 2 / 700 Batch 3 / 20 Loss: 1.4181411
# Iter 2 / 700 Batch 4 / 20 Loss: 1.4834694
# Iter 2 / 700 Batch 5 / 20 Loss: 1.4798416
# Iter 2 / 700 Batch 6 / 20 Loss: 1.7106718
# Iter 2 / 700 Batch 7 / 20 Loss: 2.1323526
# Iter 2 / 700 Batch 8 / 20 Loss: 1.6603502
# Iter 2 / 700 Batch 9 / 20 Loss: 1.6674421
# Iter 2 / 700 Batch 10 / 20 Loss: 1.6462314
# Iter 2 / 700 Batch 11 / 20 Loss: 1.5864161
# Iter 2 / 700 Batch 12 / 20 Loss: 1.2182963
# Iter 2 / 700 Batch 13 / 20 Loss: 1.4795339
# Iter 2 / 700 Batch 14 / 20 Loss: 1.5603132
# Iter 2 / 700 Batch 15 / 20 Loss: 1.1754713
# Iter 2 / 700 Batch 16 / 20 Loss: 1.2793429
# Iter 2 / 700 Batch 17 / 20 Loss: 1.1131763
# Iter 2 / 700 Batch 18 / 20 Loss: 1.3746277
# Iter 2 / 700 Batch 19 / 20 Loss: 1.3131723
# Iter 3 / 700 Batch 0 / 20 Loss: 1.1196606
# Iter 3 / 700 Batch 1 / 20 Loss: 1.0697715
# Iter 3 / 700 Batch 2 / 20 Loss: 1.3295505
# Iter 3 / 700 Batch 3 / 20 Loss: 1.2649658
# Iter 3 / 700 Batch 4 / 20 Loss: 1.1335729
# Iter 3 / 700 Batch 5 / 20 Loss: 1.3045511
# Iter 3 / 700 Batch 6 / 20 Loss: 1.3572462
# Iter 3 / 700 Batch 7 / 20 Loss: 2.0795372
# Iter 3 / 700 Batch 8 / 20 Loss: 1.3537722
# Iter 3 / 700 Batch 9 / 20 Loss: 1.4744346
# Iter 3 / 700 Batch 10 / 20 Loss: 1.4772098
# Iter 3 / 700 Batch 11 / 20 Loss: 1.4072654
# Iter 3 / 700 Batch 12 / 20 Loss: 1.0000349
# Iter 3 / 700 Batch 13 / 20 Loss: 1.2494843
# Iter 3 / 700 Batch 14 / 20 Loss: 1.5190403
# Iter 3 / 700 Batch 15 / 20 Loss: 1.1255754
# Iter 3 / 700 Batch 16 / 20 Loss: 0.97995406
# Iter 3 / 700 Batch 17 / 20 Loss: 1.0444957
# Iter 3 / 700 Batch 18 / 20 Loss: 1.2044363
# Iter 3 / 700 Batch 19 / 20 Loss: 1.2175577
# Iter 4 / 700 Batch 0 / 20 Loss: 0.9087796
# Iter 4 / 700 Batch 1 / 20 Loss: 0.9889885
# Iter 4 / 700 Batch 2 / 20 Loss: 1.1813036
# Iter 4 / 700 Batch 3 / 20 Loss: 1.1938412
# Iter 4 / 700 Batch 4 / 20 Loss: 1.0117733
# Iter 4 / 700 Batch 5 / 20 Loss: 1.2746358
# Iter 4 / 700 Batch 6 / 20 Loss: 1.2193948
# Iter 4 / 700 Batch 7 / 20 Loss: 1.5921298
# Iter 4 / 700 Batch 8 / 20 Loss: 1.3527404
# Iter 4 / 700 Batch 9 / 20 Loss: 1.3506863
# Iter 4 / 700 Batch 10 / 20 Loss: 1.2934799
# Iter 4 / 700 Batch 11 / 20 Loss: 1.4000182
# Iter 4 / 700 Batch 12 / 20 Loss: 1.0349402
# Iter 4 / 700 Batch 13 / 20 Loss: 1.1404002
# Iter 4 / 700 Batch 14 / 20 Loss: 1.3086522
# Iter 4 / 700 Batch 15 / 20 Loss: 1.0921744
# Iter 4 / 700 Batch 16 / 20 Loss: 0.8264246
# Iter 4 / 700 Batch 17 / 20 Loss: 0.9282859
# Iter 4 / 700 Batch 18 / 20 Loss: 1.1624044
# Iter 4 / 700 Batch 19 / 20 Loss: 1.1353331
# Iter 5 / 700 Batch 0 / 20 Loss: 0.76439303
# Iter 5 / 700 Batch 1 / 20 Loss: 0.9135162
# Iter 5 / 700 Batch 2 / 20 Loss: 1.141803
# Iter 5 / 700 Batch 3 / 20 Loss: 1.1133823
# Iter 5 / 700 Batch 4 / 20 Loss: 0.9597152
# Iter 5 / 700 Batch 5 / 20 Loss: 1.1383716
# Iter 5 / 700 Batch 6 / 20 Loss: 1.0746486
# Iter 5 / 700 Batch 7 / 20 Loss: 1.2887043
# Iter 5 / 700 Batch 8 / 20 Loss: 1.1961743
# Iter 5 / 700 Batch 9 / 20 Loss: 1.2783082
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-f8e4a8a6d448> in <module>()
#      40         xb,yb = batch_hist_from_df(idf=idf,x_col=x_col,y_col=y_col,
#      41                            batch_size=batch_size,offset=offset,
# ---> 42                             resize=resize_shape,bins=bins_per_channel,mode ="rgb")
#      43
#      44         loss = model.train_on_batch(xb, yb)
#
# <ipython-input-12-3ab932cb6eca> in batch_hist_from_df(idf, x_col, y_col, batch_size, offset, resize, bins, mode)
#      90     _y = np.vstack(tdf[y_col])
#      91
# ---> 92     arrays = list(map(lambda x: image_file_to_np(x,resize=resize),tdf[x_col]))
#      93     if mode == "red":
#      94         _x = np.vstack(list(map(lambda x: inp_to_hist_bycolor(x,bins=bins, channel =0),arrays)))
#
# <ipython-input-12-3ab932cb6eca> in <lambda>(x)
#      90     _y = np.vstack(tdf[y_col])
#      91
# ---> 92     arrays = list(map(lambda x: image_file_to_np(x,resize=resize),tdf[x_col]))
#      93     if mode == "red":
#      94         _x = np.vstack(list(map(lambda x: inp_to_hist_bycolor(x,bins=bins, channel =0),arrays)))
#
# <ipython-input-12-3ab932cb6eca> in image_file_to_np(ifile, resize)
#       1 def image_file_to_np(ifile,resize=(64,64)):
#       2     pil_img = Image.open(ifile)
# ----> 3     pil_img = pil_img.resize(resize,Image.ANTIALIAS)
#       4     np_img = np.asarray(pil_img)
#       5     pil_img.close()
#
# ~\Anaconda3\lib\site-packages\PIL\Image.py in resize(self, size, resample, box)
#    1743             return self.convert('RGBa').resize(size, resample, box).convert('RGBA')
#    1744
# -> 1745         self.load()
#    1746
#    1747         return self._new(self.im.resize(size, resample, box))
#
# ~\Anaconda3\lib\site-packages\PIL\ImageFile.py in load(self)
#     234
#     235                         b = b + s
# --> 236                         n, err_code = decoder.decode(b)
#     237                         if n < 0:
#     238                             break
#
# KeyboardInterrupt:

# %%
test_rows = train4.shape[0]
tbatches = int(np.ceil(test_rows/batch_size))
general_accuracy = []
ground_truths =[]
class_preds = []


for batch in range(tbatches):
    offset = batch*batch_size
    xb,yb = batch_hist_from_df(idf=train4,x_col=x_col,y_col=y_col,
                           batch_size=batch_size,offset=offset,
                            resize=resize_shape,bins=bins_per_channel)
    print(xb.shape, yb.shape)
    classes = model.predict(xb)
    print(classes)
    loss = model.evaluate(xb, yb,verbose=0)
    
    class_pred = np.argmax(classes,1)
    print(class_pred)
    print("Batch",batch,"/",tbatches,"Loss:",loss)
    ground_truth = np.argmax(yb,1)
    print(ground_truth)
    
    accuracy = sum(np.equal(class_pred,ground_truth))/batch_size
    general_accuracy.append(accuracy)   
    
    ground_truths.append(ground_truth)
    class_preds.append(class_pred)
    
    
#print(xb.shape, yb.shape)


print("Total accuracy",np.mean(general_accuracy))
# Out:
# (10, 384) (10, 6)
# [[2.67199334e-02 2.28627533e-01 3.46790031e-02 1.85384050e-01
#   1.88817874e-01 3.35771620e-01]
#  [1.89965085e-05 9.97516394e-01 2.40447070e-03 4.69144179e-05
#   1.26108871e-05 6.27266616e-07]
#  [5.77366678e-04 4.78347589e-04 1.71370909e-03 4.52886074e-04
#   9.89687741e-01 7.09002465e-03]
#  [6.37009143e-05 9.99927044e-01 9.13449912e-06 8.33267961e-08
#   9.68050085e-09 3.14252446e-08]
#  [5.43947853e-02 1.45262849e-04 8.21089864e-01 1.22950887e-02
#   1.60473224e-03 1.10470220e-01]
#  [2.08265662e-01 1.31343547e-02 3.75570804e-01 2.91151181e-02
#   1.47509333e-02 3.59163105e-01]
#  [2.22391222e-07 2.95472114e-06 1.01310525e-06 7.85226234e-07
#   9.99991298e-01 3.66222048e-06]
#  [1.59624740e-02 2.47907769e-06 9.05712204e-06 7.98087509e-04
#   9.75432456e-01 7.79545587e-03]
#  [3.87201761e-03 3.99980089e-03 4.42863464e-01 2.75274456e-01
#   1.71687245e-01 1.02303043e-01]
#  [1.95112258e-01 1.11638554e-04 1.32037789e-01 7.73667917e-02
#   2.49169581e-02 5.70454538e-01]]
# [5 1 4 1 2 2 4 4 2 5]
# Batch 0 / 16 Loss: 1.5857802629470825
# [1 2 4 1 2 1 4 4 4 2]
# (10, 384) (10, 6)
# [[1.3582430e-02 2.8198323e-01 9.5609407e-04 7.0262873e-01 4.3011559e-04
#   4.1937252e-04]
#  [2.2211900e-02 2.3309758e-03 1.3806048e-01 2.8331219e-03 8.0147600e-01
#   3.3087570e-02]
#  [1.2671448e-05 2.3256394e-03 1.2153723e-05 9.9755585e-01 1.8892604e-06
#   9.1770482e-05]
#  [3.7630353e-04 5.6110648e-04 1.2211552e-02 5.1735570e-03 9.7885555e-01
#   2.8218767e-03]
#  [7.8153342e-01 3.0843297e-03 2.0007998e-01 1.1479730e-03 1.7294411e-03
#   1.2424825e-02]
#  [3.0613623e-03 1.3667015e-02 6.0658958e-02 1.9617666e-01 7.2573692e-01
#   6.9915311e-04]
#  [9.9265891e-01 2.6903764e-04 3.1898287e-03 3.3469693e-04 1.9314426e-05
#   3.5282117e-03]
#  [5.9880004e-03 9.4254185e-03 1.8404917e-01 4.9843572e-02 2.9837498e-01
#   4.5231882e-01]
#  [9.7550142e-01 1.1370567e-04 2.1129219e-02 8.8586123e-04 2.0857346e-03
#   2.8399768e-04]
#  [7.6999972e-03 7.8422681e-04 2.9834411e-01 6.3396106e-03 5.8970517e-01
#   9.7126834e-02]
#  [2.3460833e-04 1.0674755e-04 4.6925768e-02 1.2098540e-03 1.4548351e-04
#   9.5137757e-01]
#  [7.3117420e-02 1.5000995e-03 1.1019535e-01 1.3382283e-02 5.2245664e-03
#   7.9658031e-01]
#  [6.6047922e-02 5.6833884e-04 8.2520558e-04 9.2705631e-01 5.7724374e-04
#   4.9250587e-03]
#  [3.8910967e-03 5.7313633e-01 2.6582429e-01 1.5647191e-01 4.7484203e-04
#   2.0154916e-04]
#  [1.3219557e-02 8.8645576e-04 3.9179379e-01 5.3267360e-02 5.4973830e-03
#   5.3533542e-01]
#  [5.8845035e-04 2.7276466e-03 1.4425742e-02 8.0565870e-01 1.6143435e-01
#   1.5165093e-02]]
# [1 2 5 4 5 5 3 1 5 3]
# Batch 15 / 16 Loss: 0.2775723338127136
# [1 2 5 4 5 5 3 1 2 3]
# Total accuracy 0.68125

# %%
import itertools


def plot_confusion_matrix(cm, classesNames,printCM=False,normalize=False, title='Confusion matrix', cmap=plt.cm.Blues,figsize=(12,6),dpi=80):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    cm is the confusion matrix
    """
    plt.figure(figsize=figsize,dpi=dpi)
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classesNames))
    plt.xticks(tick_marks, classesNames, rotation=45)
    plt.yticks(tick_marks, classesNames)

    if normalize:
        cm = np.round(cm.astype('float') / cm.sum(axis=1)[:, np.newaxis],2)
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    if printCM==True:
        print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
ground_truth = np.concatenate(ground_truths)
class_pred = np.concatenate(class_preds)

# %%
from sklearn.metrics import confusion_matrix


c1 = confusion_matrix(ground_truth, class_pred)

#print(class_pred.shape)

plot_confusion_matrix(c1,[])

# %%
test_rows = test4.shape[0]
tbatches = int(np.ceil(test_rows/batch_size))
general_accuracy = []
ground_truths =[]
class_preds = []


for batch in range(tbatches):
    offset = batch*batch_size
    xb,yb = batch_hist_from_df(idf=test4,x_col=x_col,y_col=y_col,
                           batch_size=batch_size,offset=offset,
                            resize=resize_shape,bins=bins_per_channel)
    print(xb.shape, yb.shape)
    classes = model.predict(xb)
    print(classes)
    loss = model.evaluate(xb, yb,verbose=0)
    
    class_pred = np.argmax(classes,1)
    print(class_pred)
    print("Batch",batch,"/",tbatches,"Loss:",loss)
    ground_truth = np.argmax(yb,1)
    print(ground_truth)
    
    accuracy = sum(np.equal(class_pred,ground_truth))/batch_size
    general_accuracy.append(accuracy)   
    
    ground_truths.append(ground_truth)
    class_preds.append(class_pred)
    
    
#print(xb.shape, yb.shape)


print("Total accuracy",np.mean(general_accuracy))

# %%
ground_truth = np.concatenate(ground_truths)
class_pred = np.concatenate(class_preds)

# %%
c1 = confusion_matrix(ground_truth, class_pred)

#print(class_pred.shape)

plot_confusion_matrix(c1,[])

# %%
emoticon_model='C:\\Users\\susmitha kolli\\Desktop\\happysad.h5'

model.save(emoticon_model)  # creates a HDF5 file 'my_model.h5'
#del model  # deletes the existing model

# %%
def show_emoji(preditClass, resize = (32,32)):
    emoji_dir = "C:\\Users\\susmitha kolli\\Desktop\\Happy emoji\\"
    emoticon_dict= {0:emoji_dir+"happy1.png", 1:emoji_dir+"happy2.jpg", 2:emoji_dir+"happy3.jpg", 3:emoji_dir+"sad1.png", 4:emoji_dir+"sad2.png", 5:emoji_dir+"sad3.png"}
    emoji_file = emoticon_dict[preditClass]
    z = image_file_to_np(emoji_file, resize = resize)
     
    plt.imshow(z)
    plt.show()
    
def predict_score(model_name,x ):
    modelx = load_model(model_name)
    classes = modelx.predict(x)
    print(classes)
    class_pred = np.argmax(classes,1)
    print(class_pred)
    classes_score = classes.flatten()[class_pred]
    print(classes_score)

    class_pred =class_pred[0]
    return class_pred, np.round(classes_score[0]*100,2)
    

def predict_img(file1, model_name,resize_img=(64,64), mode ="rgbh", bins = 128, resize_emoji = (32,32)):
    x = image_file_to_np(file1, resize=resize_img)
    if mode == "red":
        _x = inp_to_hist_bycolor(x,bins=bins, channel =0)
    elif mode == "green":
        _x = inp_to_hist_bycolor(x,bins=bins, channel =1)
    elif mode == "blue":
        _x = inp_to_hist_bycolor(x,bins=bins, channel =2)
    elif mode == "brightness":
        _x = inp_to_hist_brightness(x,bins=bins)
    elif mode == "rgb":
        _x = np_img_to_hist(x,bins=bins)
    elif mode =="rgbh":
        _x = np_img_and_bright_hist(x,bins=bins)
    pri_class,class_score  = predict_score(model_name, _x)
    print(class_score, "%")
    
    return show_emoji(pri_class, resize = resize_emoji)
    
   

def prepro_img(file1,resize_img=(64,64), mode ="rgbh", bins = 128, resize_emoji = (32,32)):
    x = image_file_to_np(file1, resize=resize_img)
    if mode == "red":
        _x = inp_to_hist_bycolor(x,bins=bins, channel =0)
    elif mode == "green":
        _x = inp_to_hist_bycolor(x,bins=bins, channel =1)
    elif mode == "blue":
        _x = inp_to_hist_bycolor(x,bins=bins, channel =2)
    elif mode == "brightness":
        _x = inp_to_hist_brightness(x,bins=bins)
    elif mode == "rgb":
        _x = np_img_to_hist(x,bins=bins)
    elif mode =="rgbh":
        _x = np_img_and_bright_hist(x,bins=bins)
    #pri_class,class_score  = predict_score(model_name, _x)
    #print(class_score, "%")
    #print("classscore: 56%" )
    #show_emoji(pri_class, resize = resize_emoji)
    return _x
   

var1 = prepro_img("C:\\Users\\susmitha kolli\\Desktop\\final_train\\happy1.15.jpg")

# %%
modelx = load_model(emoticon_model)
classes = modelx.predict(var1)
print(classes)
class_pred = np.argmax(classes,1)
print(class_pred)
classes_score = classes.flatten()[class_pred]
print(classes_score)

class_pred =class_pred[0]

predict_img("C:\\Users\\susmitha kolli\\Desktop\\final_train\\happy1.15.jpg",emoticon_model) 


def predict_score_all(model_name,x ):
    emoji_names = ["happy1","happy2","happy3","sad1","sad2","sad3"]

    modelx = load_model(model_name)
    classes = np.round(modelx.predict(x)*100,2)[0]
    print(classes)
    classes =list(classes)
    print(classes)
    #class_pred = np.argmax(classes,1)
    #classes_score = classes.flatten()[class_pred]

    #class_pred =class_pred[0]
    #return class_pred, np.round(classes_score[0]*100,2)
    fig, ax = plt.subplots()

    for _ in range(0,6):
        ax.barh(_,classes[_])

    ax.set_yticklabels(emoji_names)
    ax.invert_yaxis()
    plt.show()
    
predict_score_all(emoticon_model, var1)
